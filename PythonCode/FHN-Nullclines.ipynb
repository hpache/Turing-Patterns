# %%
a = -1.3
b = 1.16

# %%
u,v = var("u v")

# %%
# Should have spiral trajectories
plot_vector_field(((a-u)*(u-1)*u - v, b*u-v), (u,-1,1), (v,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive
